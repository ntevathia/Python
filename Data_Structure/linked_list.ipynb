# %%
class Node:
    def __init__(self, value):
        self.data = value
        self.next = None

    def get_data(self):
        return self.data

    def get_next(self):
        return self.next

    def set_data(self, value):
        self.value = value

    def set_next(self, Node):
        self.next = Node

# %%
from lolviz import *

# %%
head = Node(1)
node1 = Node(2)
node2 = Node(3)
node3 = Node(4)
node4 = Node(5)
node5 = Node(6)

head.next = node1
node1.next = node2
node2.next = node3
node3.next = node4
node4.next = node5

# %%
objviz(head)

# %%
head.get_data()
# Out:
# 1

# %%
a = head.get_next()
a.get_data()
# Out:
# 2

# %%
a.set_data(99)
a.set_next(node3)

# %%
objviz(head)

# %%
class LinkedList:
    def __init__(self):
        self.head = None
    
    def is_empty(self):
        return self.head == None
    
    def add(self, value):
        p = Node(value)
        if self.is_empty():
            self.head = p
        else:
            tmp = self.head
            while tmp.next != None:
                tmp = tmp.next    
            tmp.next = p
            
    def size(self):
        tmp = self.head
        if self.is_empty():
            print("Empty List!!")
            return
        count = 0
        while tmp!=None:
            tmp = tmp.next
            count += 1
        return count
    
    def search(self, value):
        if self.is_empty():
            print("Empty List!!")
            return

        tmp = self.head
        if tmp.data == value:
            return True
        else:
            while tmp.next!=None and tmp.data!=value:
                tmp = tmp.next
            if tmp.next==None:
                return False
            else:
                return True
                
    
    def remove(self, value):
        if self.is_empty():
            print("Empty List!!")
            return
        
        # if value is at first position
        if self.head.data == value:
            self.head = self.head.next
            print("Removed")
            return True
         
        cur = self.head
        while cur.next!=None and cur.data!=value:
            prev = cur
            cur = cur.next

        if cur.next == None:
            print("value not present in the list")
            return False # value not found
        else:
            prev.next = cur.next
            print("Removed")
            return True
        
    def __str__(self):
        if self.is_empty():
            print("Empty List!!")
            return 
        else:
            cur = self.head
            l = []
            while cur.next != None:
                l.append(cur.data)
                cur = cur.next
            return str(l)

# %%
mylist = LinkedList()

# %%
mylist.is_empty()
# Out:
# True

# %%
mylist.size()
# Out:
# Empty List!!

# %%
mylist.search(2)
# Out:
# Empty List!!

# %%
mylist.remove(2)
# Out:
# Empty List!!

# %%
# add elements
mylist.add(31)
mylist.add(77)
mylist.add(17)
mylist.add(93)
mylist.add(26)
mylist.add(54)

# %%
objviz(mylist)

# %%
print(mylist)
# Out:
# [31, 77, 17, 93, 26]

# %%
mylist.is_empty()
# Out:
# False

# %%
mylist.size()
# Out:
# 6

# %%
mylist.search(31)
# Out:
# True

# %%
mylist.search(99)
# Out:
# False

# %%
mylist.remove(77)
# Out:
# Removed
# True

# %%
objviz(mylist)

# %%
mylist.remove(54)
# Out:
# value not present in the list
# False

# %%
objviz(mylist)

# %%
mylist.remove(31)
# Out:
# Removed
# True

# %%
objviz(mylist)

# %%
mylist.remove(99)
# Out:
# value not present in the list
# False

# %% [markdown]
# ## Insert at specific position and find the position of the key value

# %%
class LinkedList:
    def __init__(self):
        self.head = None
    
    def is_empty(self):
        return self.head == None
    
    def add(self, value):
        p = Node(value)
        if self.is_empty():
            self.head = p
        else:
            tmp = self.head
            while tmp.next != None:
                tmp = tmp.next    
            tmp.next = p
    
    def size(self):
        tmp = self.head
        if self.is_empty():
            print("Empty List!!")
            return
        count = 0
        while tmp!=None:
            tmp = tmp.next
            count += 1
        return count
    
    def insert(self, value, pos):
        if self.is_empty():
            print("Empty List!!")
            return
        
        p = Node(value)
        
        if pos == 1:
            p.next = self.head
            self.head = p
            print("Inserted at first position")
            return
        
        count = 0
        cur = self.head
        while cur.next!=None and count!=pos-1:
            prev = cur
            cur = cur.next
            count += 1
        
        # handles last position 
        print("count",count)
        if cur.next==None and count+1==self.size():
            cur.next = p
            print("Inserted at last position!!")
            return
        elif cur.next==None:
            print("Position not found!")
            return
        else:
            prev.next = p
            p.next = cur
            print("Inserted!!")
            
    def get_position(self, key):
        
        cur = self.head
        found = False
        counter = 1
        while cur != None and not found:
            if cur.data == key:
                found = True
                return counter
            else:
                counter += 1
                cur = cur.next
        print("Value not present!!")

# %%
mylist = LinkedList()

# %%
mylist.insert(99, 8)
# Out:
# Empty List!!

# %%
mylist.add(31)
mylist.add(77)
mylist.add(17)
mylist.add(93)
mylist.add(26)
mylist.add(54)

# %%
objviz(mylist)

# %%
mylist.insert(99, 3)
# Out:
# count 2
# Inserted!!

# %%
objviz(mylist)

# %%
mylist.insert(100, 1)
# Out:
# Inserted at first position

# %%
objviz(mylist)

# %%
mylist.insert(200, 9)
objviz(mylist)
# Out:
# count 7
# Inserted at last position!!

# %%
mylist.get_position(31)
# Out:
# 2

# %%
mylist.get_position(200), mylist.get_position(100)
# Out:
# (9, 1)

# %%
mylist.get_position(1000)
# Out:
# Value not present!!
